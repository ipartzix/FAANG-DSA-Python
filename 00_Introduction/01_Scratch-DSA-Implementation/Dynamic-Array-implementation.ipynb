# %% [markdown]
# # Dynamic Array - by Python

# %%
import ctypes

# %%
class meraList:
    def __init__(self):
        self.size = 1
        self.n = 0
        self.A = self.__make_array(self.size)

    def __len__(self):
        return self.n

    def append(self, item):
        if self.n == self.size:
            # resize
            self.__resize(self.size * 2)

        # append
        self.A[self.n] = item
        self.n = self.n + 1

    def __resize(self, new_capacity):
        # create new array
        B = self.__make_array(new_capacity)

        # copy elements
        for i in range(self.n):
            B[i] = self.A[i]

        # reassign
        self.A = B
        self.size = new_capacity

    def __make_array(self, capacity):
        return (capacity * ctypes.py_object)()

# %%
L = meraList()

# %%
print(L)
# Out:
# <__main__.meraList object at 0x75577debe270>

# %%
L.append("hi")
L.append(3.5)
L.append(True)
L.append(234)

# %%
L = [10,20 ,30]
len(L)
# Out:
# 3
