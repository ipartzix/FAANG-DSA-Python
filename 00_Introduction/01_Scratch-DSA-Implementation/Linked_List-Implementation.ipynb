# %% [markdown]
# # Linked List Implementation

# %%
class Node:

    def __init__(self,value):
        self.data = value
        self.next = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
print(a)

# %%
print(a.data)
# Out:
# 1

# %%
print(a.next)
# Out:
# None

# %%
a.next = b
b.next = c
