# %% [markdown]
# # Linked List Implementation

# %%
class Node:

    def __init__(self,value):
        self.data = value
        self.next = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
print(a)
# Out:
# <__main__.Node object at 0x79927bfd0920>

# %%
print(a.data)
# Out:
# 1

# %%
print(a.next)
# Out:
# None

# %%
a.next = b
b.next = c

# %%
class Node:

    def __init__(self, value):
        self.data = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
       # Create an Empty a linkedList
        self.head = None
        # Num. of nodes in the LinkedList
        self.n = 0

    def __len__(self):
        return self.n

    def insert_head(self,value):
        # new node
        new_node =Node(value)
        # create cunnection
        new_node.next = self.head
        # reassign head
        self.head = new_node
        #increment n
        self.n = self.n+1

    # def traverse(self):
    #     curr = self.head
    #     while curr != None:
    #         print(curr.data)
    #         curr = curr.next


    def __str__(self):
        curr = self.head
        result =""
        while curr != None:
            result = result + str(curr.data)+ "->"
            curr = curr.next
        return result[:-2]

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            # Empty
            self.head = new_node
            self.n = self.n+1
            return

        curr = self.head
        while curr.next != None:
            curr =  curr.next

        # at the tail node
        curr.next = new_node
        self.n = self.n+1

# %%
L = LinkedList()

# %%
print(L)

# %%
len(L)
# Out:
# 0

# %%
L.insert_head(1)
L.insert_head(2)
L.insert_head(3)
L.insert_head(4)

# %%
len(L)
# Out:
# 4

# %%
print(L)
# Out:
# 4->3->2->1

# %%
L.append(5)

# %%
print(L)
# Out:
# 4->3->2->1->5
