# %% [markdown]
# # Linked List Implementation

# %%
class Node:

    def __init__(self,value):
        self.data = value
        self.next = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
print(a)
# Out:
# <__main__.Node object at 0x7dbfb51fe930>

# %%
print(a.data)
# Out:
# 1

# %%
print(a.next)
# Out:
# None

# %%
a.next = b
b.next = c

# %%
class Node:

    def __init__(self, value):
        self.data = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
       # Create an Empty a linkedList
        self.head = None
        # Num. of nodes in the LinkedList
        self.n = 0

    def __len__(self):
        return self.n

# %%
L = LinkedList()

# %%
print(L)
# Out:
# <__main__.LinkedList object at 0x7dbfb51fee40>

# %%
len(L)
# Out:
# 0
